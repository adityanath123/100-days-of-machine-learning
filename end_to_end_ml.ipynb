# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 45   6.0   66.0
# 20   6.6  120.0
# 73   4.9   61.0
# 65   8.1  166.0
# 40   4.9  134.0
# ..   ...    ...
# 94   4.7   52.0
# 80   4.9  196.0
# 9    5.1   66.0
# 47   5.2  161.0
# 62   6.0  102.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 45    1
# 20    1
# 73    0
# 65    1
# 40    0
#      ..
# 94    0
# 80    0
# 9     0
# 47    0
# 62    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 61   7.3  137.0
# 3    7.4  132.0
# 14   6.1  103.0
# 85   5.8  166.0
# 11   6.9  138.0
# 99   6.2  113.0
# 39   4.6  146.0
# 49   5.4  135.0
# 67   5.0  118.0
# 64   7.0   64.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.0249619 , -1.40158694],
#        [ 0.54340143, -0.08302083],
#        [-0.92551056, -1.52367639],
#        [ 1.83950024,  1.04020215],
#        [-0.92551056,  0.25882964],
#        [-1.44395009,  1.87041044],
#        [-1.01191715,  0.42975488],
#        [ 0.0249619 ,  0.62509801],
#        [ 0.54340143,  0.35650121],
#        [ 0.88902778,  1.25996317],
#        [-0.14785127,  0.45417277],
#        [ 1.14824754, -1.79227319],
#        [ 1.83950024,  0.62509801],
#        [ 0.11136849, -1.03531857],
#        [-0.92551056, -0.08302083],
#        [ 0.0249619 , -1.91436264],
#        [ 0.62980802,  0.74718746],
#        [ 0.7162146 , -0.00976716],
#        [-0.23425786,  0.47859066],
#        [-1.09832374, -0.05860294],
#        [ 1.58028048, -0.22952817],
#        [ 0.37058825, -0.18069239],
#        [-0.92551056,  0.77160535],
#        [-0.6662908 ,  2.45643982],
#        [ 0.97543437,  0.67393379],
#        [-0.75269739,  1.28438106],
#        [ 0.45699484,  0.16115808],
#        [ 0.62980802,  1.43088841],
#        [-1.01191715,  0.96694848],
#        [ 1.14824754, -0.91322912],
#        [-0.57988421, -0.05860294],
#        [ 0.80262119,  0.3809191 ],
#        [-2.30801596,  1.4553063 ],
#        [-1.01191715, -0.27836396],
#        [ 0.11136849,  0.20999386],
#        [-0.6662908 , -0.32719974],
#        [ 1.14824754, -0.18069239],
#        [ 1.32106072,  0.84485902],
#        [ 0.45699484,  0.89369481],
#        [ 0.45699484, -2.10970577],
#        [-1.70316985, -0.57137865],
#        [-0.57988421, -0.22952817],
#        [-0.23425786,  1.11345582],
#        [ 1.32106072,  0.16115808],
#        [-0.92551056,  0.67393379],
#        [ 0.88902778,  0.3809191 ],
#        [-0.23425786,  0.20999386],
#        [ 0.88902778, -0.27836396],
#        [ 0.97543437, -1.84110897],
#        [ 1.75309366, -1.08415435],
#        [-1.3575435 ,  0.62509801],
#        [ 0.28418167, -0.49812497],
#        [-0.83910397, -0.79113966],
#        [ 0.11136849,  0.79602324],
#        [-0.6662908 , -0.81555756],
#        [ 0.28418167,  0.1123223 ],
#        [ 0.0249619 ,  0.01465073],
#        [-0.49347762, -0.40045341],
#        [-0.49347762,  0.3809191 ],
#        [ 0.28418167,  0.08790441],
#        [-1.01191715,  1.11345582],
#        [ 0.7162146 ,  0.42975488],
#        [ 1.4074673 , -0.83997545],
#        [ 2.18512659, -0.08302083],
#        [-0.23425786,  0.40533699],
#        [ 0.7162146 , -0.81555756],
#        [ 0.11136849, -1.42600483],
#        [-1.70316985, -1.18182592],
#        [-0.06144468, -0.4248713 ],
#        [ 0.37058825,  0.42975488],
#        [ 0.7162146 , -0.27836396],
#        [-0.83910397, -1.47484061],
#        [ 0.88902778,  1.84599255],
#        [-0.75269739,  0.1123223 ],
#        [ 1.32106072, -1.52367639],
#        [ 2.01231342,  1.08903793],
#        [ 1.4074673 ,  0.1123223 ],
#        [-0.49347762, -0.22952817],
#        [-1.09832374, -0.88881123],
#        [ 0.45699484, -0.81555756],
#        [-1.78957644, -0.35161763],
#        [-2.13520279,  2.67620084],
#        [-0.6662908 ,  0.20999386],
#        [-1.3575435 , -1.98761632],
#        [ 0.80262119, -0.66905021],
#        [-1.09832374, -1.74343741],
#        [-0.92551056,  1.77273888],
#        [-0.75269739, -1.40158694],
#        [-0.6662908 ,  0.9181127 ],
#        [ 0.0249619 , -0.52254286]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.14824754,  0.33208332],
#        [ 1.23465413,  0.20999386],
#        [ 0.11136849, -0.49812497],
#        [-0.14785127,  1.04020215],
#        [ 0.80262119,  0.35650121],
#        [ 0.19777508, -0.25394607],
#        [-1.18473032,  0.55184433],
#        [-0.49347762,  0.28324753],
#        [-0.83910397, -0.13185661],
#        [ 0.88902778, -1.45042272]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 61    1
# 3     1
# 14    0
# 85    1
# 11    1
# 99    1
# 39    0
# 49    0
# 67    0
# 64    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
